# %% [markdown]
# # **Data Scrapping From Hello Work**

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # **Data Collection**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# ==== HEADERS ====
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# ==== FONCTION : RÉCUPÉRER LES LIENS DES OFFRES ====
def get_offer_links_from_pages(base_url, max_pages=3):
    all_links = set()

    for page in range(1, max_pages + 1):
        page_url = f"{base_url}&p={page}"
        print(f"Page {page} → {page_url}")

        try:
            response = requests.get(page_url, headers=headers)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Erreur page {page} : {e}")
            continue

        soup = BeautifulSoup(response.content, "html.parser")

        for link in soup.find_all("a", href=True):
            href = link["href"]
            if "/fr-fr/emplois/" in href:
                full_link = "https://www.hellowork.com" + href
                all_links.add(full_link)

        time.sleep(1)

    return list(all_links)


# ==== FONCTION : SCRAPER UNE OFFRE ====
def scrape_offer_details(url):
    print(f"Scraping : {url}")
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Erreur : {e}")
        return {}

    soup = BeautifulSoup(response.content, "html.parser")

    # === Infos principales
    job_title_el = soup.find("span", {"data-cy": "jobTitle"})
    job_title = job_title_el.get_text(strip=True) if job_title_el else ""

    entreprise = lieu = contrat = ""

    if job_title_el:
        h1_block = job_title_el.find_parent("h1")
        h1_spans = h1_block.find_all("span")
        if len(h1_spans) >= 2:
            entreprise = h1_spans[1].get_text(strip=True)

        next_spans = h1_block.find_all_next("span", class_="tw-inline-flex tw-typo-m tw-text-grey", limit=2)
        if len(next_spans) > 0:
            lieu = next_spans[0].get_text(strip=True)
        if len(next_spans) > 1:
            contrat = next_spans[1].get_text(strip=True)

    # === Description du poste
    try:
        description_tag = soup.find('h2', string=lambda s: s and 'missions' in s.lower())
        description = ""
        if description_tag:
            description_elements = []
            for elem in description_tag.find_all_next():
                if elem.name == "h2":
                    break
                if elem.name in ["p", "ul", "ol"]:
                    description_elements.append(elem.get_text(" ", strip=True))
            description = "\n".join(description_elements)
    except Exception as e:
        print(f"Erreur description : {e}")
        description = ""

    # === Profil recherché
    try:
        profil_tag = soup.find('h2', string=lambda s: s and 'profil' in s.lower())
        profil = ""
        if profil_tag:
            profil_elements = []
            for elem in profil_tag.find_all_next():
                if elem.name == "h2":
                    break
                if elem.name in ["p", "ul", "ol"]:
                    profil_elements.append(elem.get_text(" ", strip=True))
            profil = "\n".join(profil_elements)
    except Exception as e:
        print(f"Erreur profil : {e}")
        profil = ""

    # === Infos secondaires
    infos = soup.select_one("section.tw-mb-8 ul")
    infos_list = infos.find_all("li") if infos else []

    secteur = niveau = experience = ""
    teletravail = False

    for li in infos_list:
        txt = li.get_text(strip=True).lower()
        if "secteur" in txt or "service" in txt:
            secteur = li.get_text(strip=True)
        elif "exp." in txt:
            experience = li.get_text(strip=True)
        elif "bac" in txt:
            niveau = li.get_text(strip=True)
        elif "télétravail" in txt:
            teletravail = True

    salaire_el = soup.select_one(".tw-tag-attractive-s")
    salaire = salaire_el.get_text(strip=True) if salaire_el else ""

    return {
        "URL": url,
        "Titre": job_title,
        "Entreprise": entreprise,
        "Lieu": lieu,
        "Contrat": contrat,
        "Salaire": salaire,
        "Secteur": secteur,
        "Télétravail": teletravail,
        "Niveau": niveau,
        "Expérience": experience,
        "Description": description,
        "Profil": profil
    }


# ==== MAIN ====
if __name__ == "__main__":
    search_url = "https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france"
    offer_links = get_offer_links_from_pages(search_url, max_pages=20)

    print(f"Total liens récupérés : {len(offer_links)}")

    data = []

    try:
        for i, link in enumerate(offer_links):
            result = scrape_offer_details(link)
            if result:
                data.append(result)
            time.sleep(1)
    except KeyboardInterrupt:
        print("Interruption manuelle. Enregistrement des résultats partiels...")

    if data:
        df = pd.DataFrame(data)
        df.to_csv("hellowork_offres.csv", index=False)
        print("Fichier généré : hellowork_offres.csv")
    else:
        print("Aucune donnée trouvée.")
# Out:
# Page 1 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=1
# Page 2 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=2
# Page 3 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=3
# Page 4 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=4
# Page 5 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=5
# Page 6 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=6
# Page 7 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=7
# Page 8 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=8
# Page 9 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=9
# Page 10 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=10
# Page 11 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=11
# Page 12 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=12
# Page 13 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=13
# Page 14 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=14
# Page 15 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=15
# Page 16 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=16
# Page 17 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=17
# Page 18 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=18
# Page 19 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=19
# Page 20 → https://www.hellowork.com/fr-fr/emploi/recherche.html?k=ingenieur+informatique&l=france&p=20
# Total liens récupérés : 568
# Scraping : https://www.hellowork.com/fr-fr/emplois/63525045.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64128525.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63570506.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63902382.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64205442.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848778.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57646948.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63598778.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64195194.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64033303.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60615720.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63993589.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64179698.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62630564.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47339859.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62462126.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257044.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628079.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56708334.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64124930.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63808622.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57894860.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63905484.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628072.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62679984.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63459622.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628023.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63808246.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627984.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64283662.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64127394.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61509408.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62831292.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/28491583.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62723653.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64174283.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64296268.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64069597.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64116847.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60192800.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60266233.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57030627.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628016.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63905693.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63435401.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62683569.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628019.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63027340.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62127852.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63952469.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58107334.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/54216780.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63623460.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270754.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61412835.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59174067.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64289780.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62967697.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56341298.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628017.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628007.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62567730.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63909211.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64235984.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64298306.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64273180.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64032321.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59789268.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64170551.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64030569.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60347955.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62573566.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63017800.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61608303.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/42057452.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270418.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627988.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/34616150.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63556652.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63594809.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64073974.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64246378.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257421.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64030001.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64282857.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48906501.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59537156.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64248859.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63903714.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62813888.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59205638.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64170091.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60364758.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60513909.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64176554.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62307022.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62922186.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63762207.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60996934.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64126737.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628026.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63287626.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61887131.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62457091.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61060387.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63764241.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48034029.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63584899.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60370387.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59608387.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64298863.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63902848.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61973235.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63146821.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47339446.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64110267.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62967706.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62902078.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62273982.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64174258.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62688428.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63322248.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/55260431.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64269543.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628124.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/51415527.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48415994.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64154398.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61671594.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/49455591.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627998.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628091.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/37672336.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/46385465.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62389347.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62995118.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64036265.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/46145071.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64171837.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64004677.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59260318.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63849301.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62562376.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60340311.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64259999.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63710808.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64082468.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/44423277.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/53830803.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62692745.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59316535.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63058950.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63822601.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63849055.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64035936.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61455741.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63441097.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64079378.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627983.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628013.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59341973.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61388650.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628034.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61761103.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63790965.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64066112.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48906395.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58075926.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63432312.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60277482.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64106337.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64030606.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64036263.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62532899.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64271039.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64036646.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63595391.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62306619.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61607265.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64037025.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848822.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63800590.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57597146.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58678834.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/53826152.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63733005.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64040628.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64207552.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64033337.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64121571.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62793815.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64095665.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56076527.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62060076.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62977180.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63118092.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60367128.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63805614.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63172156.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64188260.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628008.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64133883.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63429936.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64018028.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64135237.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628018.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64248381.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60332576.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63541814.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62831276.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57030511.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61683054.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63859439.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64235474.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64058611.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56180686.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61497106.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64013058.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63737013.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/46521260.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62306932.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64066367.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64252052.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64079376.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848771.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61950305.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61541089.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64200785.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257487.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47824669.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62988190.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62382884.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48494159.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63974235.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62706819.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63959657.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63970959.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628011.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63118319.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64232078.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63700592.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63741272.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64110248.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/45397840.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64036278.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63111809.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63191246.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63902815.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270950.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48905066.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60367135.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/45764941.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56733000.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257111.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270506.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61218220.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63805620.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64141131.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62779876.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64261961.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62739639.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64206130.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63211666.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60137370.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62910258.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64119174.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63098503.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62828554.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62784544.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63435718.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270604.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64046641.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59369441.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63809050.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63397533.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/50840860.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60430342.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64232597.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/51337707.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63044525.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62692518.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64091933.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60417846.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63940784.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257050.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59303201.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64126900.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60135695.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63583885.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63807552.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61696607.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48279493.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628010.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63441021.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64142175.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59260303.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60137375.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/54217190.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64262588.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64192120.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62235964.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63300615.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60672071.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64110755.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628030.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61970003.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63241226.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60277579.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62306950.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627987.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63512679.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628014.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63978312.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64082480.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64142522.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64036291.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64197760.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63737461.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64159219.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62316456.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64183992.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59840748.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63860014.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64259648.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61915769.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63894360.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64068680.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64222157.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848800.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63983362.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62306892.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58070791.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64176559.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62797669.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270772.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64039857.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63764432.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64212166.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64243390.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56391844.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848795.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63945096.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628020.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62667186.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60974093.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63855851.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62306737.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63501409.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63903735.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627977.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64143709.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47349938.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62562713.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63729088.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63554787.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63899630.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64156125.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60146311.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59244030.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/53584792.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62831934.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270524.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64105680.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63035257.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63802874.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58484443.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63899650.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64049452.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63656445.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61550418.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/50527667.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628012.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62988791.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62715689.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63956631.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63945398.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64261882.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61717292.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64188433.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63432281.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62533179.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62670719.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64085870.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60418786.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62073112.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64271021.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60317639.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270614.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64050683.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848801.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/51346256.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62692747.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64117645.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61468161.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63732896.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/45909476.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63903164.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64210188.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64086915.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60411111.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47824283.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64176553.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63737010.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61901011.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63790925.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62831284.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62475264.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62422847.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61183557.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61700935.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57907697.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64059409.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64296598.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63719537.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33256683.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63903931.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61467318.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62840471.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63029493.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60377828.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257485.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64106544.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628015.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60280947.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64039853.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62958982.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63998119.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64129247.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57646885.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63909213.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56091512.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62654332.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62992073.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62969155.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63848756.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64059476.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64133887.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64059972.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62826760.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63513460.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628113.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56697378.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64140967.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64129192.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64140989.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63252307.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62831220.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64308831.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64194398.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64039859.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61145687.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64246531.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627991.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61370217.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62948397.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63029367.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63610127.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62956355.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63093664.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62642071.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64079236.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59789269.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62597762.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62934650.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60076495.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62841885.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56180681.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61632873.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63834816.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270536.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/51346232.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/46478273.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62144576.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63808274.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63429854.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/47339660.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64126805.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63537192.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64079371.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63641130.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628035.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/55396820.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48906369.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63771325.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64269365.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62165645.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64154051.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64065389.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63905519.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61591346.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63963359.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56844850.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64292323.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64272562.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60312513.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60347940.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62949488.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61408675.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/33257425.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62521663.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628032.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61502924.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63801862.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63640991.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/58875072.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61218622.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59187275.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61607316.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56844693.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59285022.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64176555.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64046099.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64154110.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61506749.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61953677.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62378590.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62522467.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57265285.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64263651.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628135.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64308412.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64194399.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64199888.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63885199.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64200087.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64155231.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/57208736.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64261752.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628027.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64270850.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64227653.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48279516.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63808187.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61344562.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62995065.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63730385.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63904331.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60090974.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60265391.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/45570676.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64134911.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63969528.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63849435.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628003.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59369433.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63525087.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63247427.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/56844788.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64110776.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/61498043.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64252126.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62748105.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628022.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/62894451.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63593759.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64033713.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/59084369.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64095803.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64041671.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/48981091.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63735185.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628123.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64260096.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/64082368.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/52899171.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63628021.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/60331834.html
# Scraping : https://www.hellowork.com/fr-fr/emplois/63627978.html
# Fichier généré : hellowork_offres.csv

# %% [markdown]
# Converting Description & Profil to Lowercase in order to extract skills from

# %%
import pandas as pd


df = pd.read_csv("/content/hellowork_offres.csv")

# Mettre en minuscules uniquement les colonnes "Description" et "Profil"
for col in ["Description", "Profil"]:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: x.lower() if isinstance(x, str) else x)

)
df.to_csv("hellowork_offres.csv", index=False)

print("Les colonnes 'Description' et 'Profil' ont été mises en minuscules.")
# Out:
# Les colonnes 'Description' et 'Profil' ont été mises en minuscules.

# %%
# !pip install -U spacy
# !python -m spacy download fr_core_news_md
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting fr-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.8.0/fr_core_news_md-3.8.0-py3-none-any.whl (45.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: fr-core-news-md
# Successfully installed fr-core-news-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# Extracting skills from Description and Profil based on a skills file

# %%
import pandas as pd
import spacy
import re


nlp = spacy.load("fr_core_news_md")

#  Charger la liste des compétences depuis ton fichier CSV
skills_df = pd.read_csv("/content/data_base_competences.csv")
SKILLS = set(skill.strip().lower() for skill in skills_df['hardskills'].dropna())

#  Fonction de détection simple
def detect_skills(text):
    if not isinstance(text, str):
        return "Non spécifié"

    text = text.lower()
    found = set()

    for skill in SKILLS:
        # Si la compétence contient des caractères spéciaux, ne pas utiliser \b
        if any(char in skill for char in ['+', '#', '.', '_']):
            pattern = re.escape(skill)
        else:
            pattern = r'\b' + re.escape(skill) + r'\b'

        if re.search(pattern, text):
            found.add(skill)

    return ", ".join(sorted(found)) if found else "Non spécifié"


df = pd.read_csv("/content/hellowork_offres.csv")


df["Compétences"] = df.apply(
    lambda row: detect_skills(f"{row['Description']} {row['Profil']}"), axis=1
)

df.to_csv("/content/hellowork_offres_competences.csv", index=False)

print(" Extraction terminée. Fichier enregistré : hellowork_offres_competences.csv")
# Out:
#  Extraction terminée. Fichier enregistré : hellowork_offres_competences.csv

# %% [markdown]
# # **Data Pre-Processing**

# %% [markdown]
# Removing records with no skills detected and non used columnn :Description &Profil

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/hellowork_offres_competences.csv")


df = df[df["Compétences"] != "Non spécifié"]

df = df.drop(columns=["Description","Profil"])


df.to_csv("new_data_offers.csv", index=False)

# %% [markdown]
# Nb competences in each offer

# %%
df = pd.read_csv("/content/new_data_offers.csv")


df["Nb_Competences"] = df["Compétences"].fillna("").apply(lambda x: len(x.split()))


df.to_csv("new_data_offers.csv", index=False)

# %% [markdown]
# Converting all the salaries to /year

# %%
import pandas as pd
import numpy as np
import re

def convertir_salaire(s):
    try:
        if pd.isna(s):
            return None


        s = s.lower().replace('\u202f', ' ').replace('\xa0', ' ').strip()
        s = s.replace("/an", "/ an").replace("/mois", "/ mois").replace("/jour", "/ jour").replace("/h", "/ h").replace("/heure", "/ h")

        # Corriger les formats comme "12-15 / heure" ou "13 - 14 / heure"
        if "/ h" in s and "€" not in s:
            s = s.replace("/ h", "€ / h")
        if "/ jour" in s and "€" not in s:
            s = s.replace("/ jour", "€ / jour")
        if "/ mois" in s and "€" not in s:
            s = s.replace("/ mois", "€ / mois")
        if "/ an" in s and "€" not in s:
            s = s.replace("/ an", "€ / an")


        s = re.sub(r"(\d)\s+(\d{3})", r"\1\2", s)

        # Cas / an
        if "/ an" in s:
            parts = s.replace("€ / an", "").strip().split("-")
            if len(parts) == 2:
                min_val = float(parts[0].strip().replace(" ", "").replace(",", "."))
                max_val = float(parts[1].strip().replace(" ", "").replace(",", "."))
            else:
                val = float(parts[0].strip().replace(" ", "").replace(",", "."))
                min_val = max_val = val
            return f"{min_val:,.2f} - {max_val:,.2f} € / an".replace(",", " ").replace(".", ",")

        # Cas / mois → x12
        elif "/ mois" in s:
            parts = s.replace("€ / mois", "").strip().split("-")
            if len(parts) == 2:
                min_val, max_val = [float(p.strip().replace(" ", "").replace(",", ".")) for p in parts]
            else:
                val = float(parts[0].strip().replace(" ", "").replace(",", "."))
                min_val = max_val = val
            return f"{min_val*12:,.2f} - {max_val*12:,.2f} € / an".replace(",", " ").replace(".", ",")

        # Cas / h ou / heure → x35*52
        elif re.search(r"/ ?(h|heure)", s):
            s = s.replace("€ / h", "").replace("€ / heure", "").replace("/ h", "").replace("/ heure", "").strip()
            parts = s.split("-")
            if len(parts) == 2:
                min_val, max_val = [float(p.strip().replace(" ", "").replace(",", ".")) for p in parts]
            else:
                val = float(parts[0].strip().replace(" ", "").replace(",", "."))
                min_val = max_val = val
            heures_annuelles = 35 * 52
            return f"{min_val*heures_annuelles:,.2f} - {max_val*heures_annuelles:,.2f} € / an".replace(",", " ").replace(".", ",")

        # Cas / jour → x220
        elif "/ jour" in s:
            parts = s.replace("€ / jour", "").strip().split("-")
            if len(parts) == 2:
                min_val, max_val = [float(p.strip().replace(" ", "").replace(",", ".")) for p in parts]
            else:
                val = float(parts[0].strip().replace(" ", "").replace(",", "."))
                min_val = max_val = val
            jours_annuels = 220
            return f"{min_val*jours_annuels:,.2f} - {max_val*jours_annuels:,.2f} € / an".replace(",", " ").replace(".", ",")

        return s
    except:
        return s


df = pd.read_csv("/content/new_data_offers.csv")


df["Salaire"] = df["Salaire"].apply(convertir_salaire)

df.to_csv("/content/new_data_offers.csv", index=False)

# %% [markdown]
# Ensure all salaries are annual

# %%
df = pd.read_csv("/content/new_data_offers.csv")

# Filtrer les lignes où "Salaire" ne contient pas "an"
salaire_non_annuel = df[df["Salaire"].notna() & ~df["Salaire"].str.contains("an", case=False, na=False)]

print("Nombre de salaires non annuels :", salaire_non_annuel.shape[0])
display(salaire_non_annuel[["Salaire"]])
# Out:
# Nombre de salaires non annuels : 0
# Empty DataFrame
# Columns: [Salaire]
# Index: []

# %% [markdown]
# # Missing Values treatment

# %%
import pandas as pd
df = pd.read_csv("/content/new_data_offers.csv")

# Compter les valeurs manquantes par colonne
missing_exp = df["Expérience"].isna().sum()
missing_secteur = df["Secteur"].isna().sum()
missing_niveau = df["Niveau"].isna().sum()
missing_teletravail = df["Télétravail"].isna().sum()
missing_salaire = df["Salaire"].isna().sum()
missing_entreprise = df["Entreprise"].isna().sum()
missing_lieu = df["Lieu"].isna().sum()
missing_contrat = df["Contrat"].isna().sum()

# Affichage lisible et regroupé
print(" Valeurs manquantes par colonne :\n")
print(f"• Expérience     : {missing_exp}")
print(f"• Secteur        : {missing_secteur}")
print(f"• Niveau         : {missing_niveau}")
print(f"• Télétravail    : {missing_teletravail}")
print(f"• Salaire        : {missing_salaire}")
print(f"• Entreprise     : {missing_entreprise}")
print(f"• Lieu           : {missing_lieu}")
print(f"• Contrat        : {missing_contrat}")
# Out:
#  Valeurs manquantes par colonne :
#
# • Expérience     : 145
# • Secteur        : 139
# • Niveau         : 2
# • Télétravail    : 0
# • Salaire        : 66
# • Entreprise     : 3
# • Lieu           : 0
# • Contrat        : 0

# %% [markdown]
# Replace each Experience based on same type of offer

# %%
import matplotlib.pyplot as plt


df = pd.read_csv("/content/new_data_offers.csv")

# Remplir 'Expérience' si manquante dependamment du 'Titre'
df.loc[df["Expérience"].isna() & df["Titre"].str.contains("ingénieur|Ingenieur|Consultant|Engineer|spécialiste", case=False, na=False), "Expérience"] = "Exp. 1 à 7 ans"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains("Stage|stagiaire", case=False, na=False), "Expérience"] = "0"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"alternance|alternant|apprentissage|apprenti", case=False, na=False), "Expérience"] = "0"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"Informaticien", case=False, na=False), "Expérience"] = "Exp. 1 à 5 ans"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"Architecte", case=False, na=False), "Expérience"] = "Exp. 8 à 12 ans"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"Senior", case=False, na=False), "Expérience"] = "Exp. 5 à 8 ans"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"Expert", case=False, na=False), "Expérience"] = "Exp. 4 à 10 ans"
df.loc[df["Expérience"].isna() & df["Titre"].str.contains( r"Doctorant", case=False, na=False), "Expérience"] = "Exp. 0 à 2 ans"

df.to_csv("/content/new_data_offers.csv", index=False)

# %%
missing_exp_df = df[df["Expérience"].isna()]

print("Nombre de lignes avec 'Expérience' manquante :", missing_exp_df.shape[0])

from IPython.display import display
display(missing_exp_df)
# Out:
# Nombre de lignes avec 'Expérience' manquante : 5
#                                                    URL  \
# 56   https://www.hellowork.com/fr-fr/emplois/616083...
# 61   https://www.hellowork.com/fr-fr/emplois/640739...
# 143  https://www.hellowork.com/fr-fr/emplois/640370...
# 273  https://www.hellowork.com/fr-fr/emplois/642707...
# 338  https://www.hellowork.com/fr-fr/emplois/640594...
#
#                                                  Titre  \
# 56                           Pentester Web & Infra H/F
# 61                Chargé de Gouvernance de Données H/F
# 143           Administrateur Sécurité Informatique H/F
# 273  Hardware - Software Cybersecurity Of Embedded ...
# 338                                     Pentesteur H/F
#
#                           Entreprise                         Lieu Contrat  \
# 56   BPCE Infogérance & Technologies                   Paris - 75     CDI
# 61                 Thélem assurances                   Chécy - 45     CDD
# 143             LABASTIE HEADHUNTING                   Paris - 75     CDI
# 273                              CEA                  Saclay - 91     CDD
# 338                   EMITECH GROUPE  Montigny-le-Bretonneux - 78     CDI
#
#                           Salaire                   Secteur  Télétravail  \
# 56   55 000,00 - 65 000,00 € / an                       NaN         True
# 61   21 600,00 - 21 600,00 € / an                       NaN        False
# 143  55 000,00 - 65 000,00 € / an  Services aux Entreprises         True
# 273  35 000,00 - 50 000,00 € / an                       NaN        False
# 338  55 000,00 - 65 000,00 € / an                       NaN        False
#
#      Niveau Expérience                                        Compétences  \
# 56   Bac +5        NaN   agile, framework, javascript, python, validation
# 61   Bac +5        NaN  automatisation, excel, gestion des incidents, ...
# 143  Bac +5        NaN                     hardening, office 365, réseaux
# 273  Bac +5        NaN                                             c, c++
# 338  Bac +5        NaN  automatisation, cybersécurité, documentation t...
#
#      Nb_Competences
# 56                5
# 61                9
# 143               4
# 273               2
# 338               6

# %%
df = df.dropna(subset=["Entreprise"])


df.to_csv("/content/new_data_offers.csv", index=False)

print(f"Nombre de lignes restantes : {len(df)}")
# Out:
# Nombre de lignes restantes : 452

# %%
missing_entreprise = df["Entreprise"].isna().sum()
print(f"• Entreprise     : {missing_entreprise}")
# Out:
# • Entreprise     : 0

# %% [markdown]
# Replacing Salaries by mean

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("/content/new_data_offers.csv")


def extraire_moyenne_salaire(s):
    try:
        if pd.isna(s):
            return np.nan
        s = s.replace("€", "").replace("/ an", "").replace(",", ".").replace('\u202f', ' ').replace('\xa0', ' ').strip()
        parts = s.split("-")
        if len(parts) == 2:
            min_val = float(parts[0].strip().replace(" ", ""))
            max_val = float(parts[1].strip().replace(" ", ""))
            return (min_val + max_val) / 2
        else:
            val = float(parts[0].strip().replace(" ", ""))
            return val
    except:
        return np.nan


df["Salaire_moyen_temp"] = df["Salaire"].apply(extraire_moyenne_salaire)


moyenne_globale = round(df["Salaire_moyen_temp"].mean(), 2)


texte_moyenne = f"{moyenne_globale:,.2f} - {moyenne_globale:,.2f} € / an".replace(",", " ").replace(".", ",")


df["Salaire"] = df["Salaire"].fillna(texte_moyenne)


df = df.drop(columns=["Salaire_moyen_temp"])


df.to_csv("/content/new_data_offers.csv", index=False)

print(f" Moyenne insérée dans les valeurs manquantes : {texte_moyenne}")
# Out:
#  Moyenne insérée dans les valeurs manquantes : 41 160,07 - 41 160,07 € / an

# %%
missing_entreprise = df["Salaire"].isna().sum()
print(f"• Salaire    : {missing_entreprise}")
# Out:
# • Salaire    : 0

# %% [markdown]
# # Organize Types of variables

# %% [markdown]
# Converting salary to numerical

# %%
import numpy as np

# %%
df = pd.read_csv("/content/new_data_offers.csv")


def extraire_salaire_moyen(s):
    try:
        if pd.isna(s):
            return np.nan
        s = s.replace('\u202f', ' ').replace('\xa0', ' ').strip().lower()
        s = s.replace("€", "").replace("/ an", "").strip()
        parts = s.split("-")
        if len(parts) == 2:
            min_val = float(parts[0].strip().replace(" ", "").replace(",", "."))
            max_val = float(parts[1].strip().replace(" ", "").replace(",", "."))
            return round((min_val + max_val) / 2, 2)
        else:
            val = float(parts[0].strip().replace(" ", "").replace(",", "."))
            return round(val, 2)
    except:
        return np.nan


df["Salaire"] = df["Salaire"].apply(extraire_salaire_moyen)
r
df.to_csv("/content/new_data_offers.csv", index=False)

df[["Salaire"]].head()
# Out:
#     Salaire
# 0  13729.74
# 1       NaN
# 2  50000.00
# 3  52500.00
# 4  36000.00

# %% [markdown]
# Separate City & Depart

# %%
df[["Ville", "Département"]] = df["Lieu"].str.extract(r"^(.*?)\s*-\s*(\d+)$")


df["Département"] = pd.to_numeric(df["Département"], errors="coerce")


df = df.drop(columns=["Lieu"])


colonnes_ordre = [
    "URL", "Titre", "Entreprise", "Ville", "Département", "Contrat", "Salaire", "Secteur",
    "Télétravail", "Niveau", "Expérience", "Compétences", "Nb_Competences"
]
df = df[colonnes_ordre]


df.to_csv("/content/new_data_offers.csv", index=False)


df.head()
# Out:
#                                                  URL  \
# 0  https://www.hellowork.com/fr-fr/emplois/641285...
# 1  https://www.hellowork.com/fr-fr/emplois/635705...
# 2  https://www.hellowork.com/fr-fr/emplois/638487...
# 3  https://www.hellowork.com/fr-fr/emplois/576469...
# 4  https://www.hellowork.com/fr-fr/emplois/635987...
#
#                                                Titre        Entreprise  \
# 0  Alternance Apprenti Informatique Industrielle H/F            Tereos
# 1           Ingénieur de Production Informatique H/F              Open
# 2               Ingénieur Secops - Cybersécurité H/F           Lutessa
# 3                         Ingénieur Dev - DevOps H/F           Meritis
# 4               Expert Informatique Industrielle H/F  Coris Innovation
#
#           Ville  Département     Contrat                       Salaire  \
# 0  Marckolsheim         67.0  Alternance   5 837,88 - 21 621,60 € / an
# 1         Tours         37.0         CDI  41 160,07 - 41 160,07 € / an
# 2    La Défense         92.0         CDI  50 000,00 - 55 000,00 € / an
# 3          Biot          6.0         CDI  30 000,00 - 42 000,00 € / an
# 4      Grenoble         38.0         CDI  45 000,00 - 50 000,00 € / an
#
#                       Secteur  Télétravail  Niveau       Expérience  \
# 0                         NaN        False  Bac +5                0
# 1  Secteur informatique • ESN         True  Bac +5   Exp. 1 à 7 ans
# 2  Secteur informatique • ESN         True  Bac +5   Exp. 1 à 7 ans
# 3  Secteur informatique • ESN        False  Bac +5   Exp. 1 à 7 ans
# 4    Services aux Entreprises        False  Bac +5  Exp. 4 à 10 ans
#
#                                          Compétences  Nb_Competences
# 0  c, excel, informatique industrielle, réseau, r...               7
# 1  analyse technique, automatisation, cloud, devo...              11
# 2                   analyse technique, cybersécurité               3
# 3  agile, ansible, automatisation, docker, gestio...              12
# 4  api, automatisation, erp, ia, ihm, informatiqu...              23

# %% [markdown]
# Testing the types of contract

# %%
df = pd.read_csv("/content/new_data_offers.csv")


contrats_valides = ["intérim", "cdi", "cdd", "indépendant", "alternance", "stage"]


contrats_autres = df[df["Contrat"].notna() & ~df["Contrat"].str.lower().isin(contrats_valides)]


print(f"Nombre de contrats hors CDI, CDD, Intérim, Indépendant, Alternance, Stage : {contrats_autres.shape[0]}")
display(contrats_autres[["Contrat"]])
# Out:
# Nombre de contrats hors CDI, CDD, Intérim, Indépendant, Alternance, Stage : 0
# Empty DataFrame
# Columns: [Contrat]
# Index: []

# %% [markdown]
# Converting Niveau & Experience to Numerical

# %%
import pandas as pd
import re
import numpy as np


df = pd.read_csv("/content/new_data_offers.csv")


def convertir_niveau(val):
    try:
        if pd.isna(val):
            return np.nan
        # Extraire le nombre après "Bac +"
        match = re.search(r"\+?(\d+)", str(val))
        if match:
            return int(match.group(1))
        else:
            return np.nan
    except:
        return np.nan


def convertir_experience(val):
    try:
        if pd.isna(val):
            return np.nan
        # Extraire le premier chiffre
        match = re.search(r"(\d+)", str(val))
        if match:
            return int(match.group(1))
        else:
            return np.nan
    except:
        return np.nan

df["Niveau"] = df["Niveau"].apply(convertir_niveau)
df["Expérience"] = df["Expérience"].apply(convertir_experience)

df.to_csv("/content/new_data_offers.csv", index=False)

df[["Niveau", "Expérience"]].head()
# Out:
#    Niveau  Expérience
# 0     5.0         0.0
# 1     5.0         1.0
# 2     5.0         1.0
# 3     5.0         1.0
# 4     5.0         4.0

# %% [markdown]
# Converting salaries to Numerical

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/new_data_offers.csv")

def extraire_moyenne_salaire(s):
    try:
        if pd.isna(s):
            return np.nan
        # Nettoyage
        s = s.replace('\u202f', ' ').replace('\xa0', ' ').lower()
        s = s.replace("€", "").replace("/ an", "").strip()
        parts = s.split("-")
        if len(parts) == 2:
            min_val = float(parts[0].strip().replace(" ", "").replace(",", "."))
            max_val = float(parts[1].strip().replace(" ", "").replace(",", "."))
            return round((min_val + max_val) / 2, 2)
        else:
            val = float(parts[0].strip().replace(" ", "").replace(",", "."))
            return round(val, 2)
    except:
        return np.nan


df["Salaire"] = df["Salaire"].apply(extraire_moyenne_salaire)

df.to_csv("/content/new_data_offers.csv", index=False)


df[["Salaire"]].head()
# Out:
#     Salaire
# 0  13729.74
# 1  41160.07
# 2  52500.00
# 3  36000.00
# 4  47500.00

# %% [markdown]
# Converting Dept, Nv, Exp to numerical

# %%
df = pd.read_csv("/content/new_data_offers.csv")


df["Département"] = pd.to_numeric(df["Département"], errors="coerce").round().astype("Int64")
df["Niveau"] = pd.to_numeric(df["Niveau"], errors="coerce").round().astype("Int64")
df["Expérience"] = pd.to_numeric(df["Expérience"], errors="coerce").round().astype("Int64")


df.to_csv("/content/new_data_offers.csv", index=False)


df[["Département", "Niveau", "Expérience"]].head()
# Out:
#    Département  Niveau  Expérience
# 0           67       5           0
# 1           37       5           1
# 2           92       5           1
# 3            6       5           1
# 4           38       5           4
